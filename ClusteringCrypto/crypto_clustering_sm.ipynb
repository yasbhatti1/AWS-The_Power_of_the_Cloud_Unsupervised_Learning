# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
#!pip install altair
import requests
import pandas as pd
from pathlib import Path
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import altair as alt

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
#Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

resp = requests.get(url)
response_content = resp.content
data = resp.json()

# %%
# save crypto data as coin_data
coin_data = data['Data']

# %%
# Create a Datafrane and then Transpose datframe (Columns to Rows)
crypto_df = pd.DataFrame(coin_data)
crypto_df = crypto_df.T
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300  300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365  365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404  404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 433  433 Token is a decentralised soccer platform t...         Finished  ...
#
#     MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType BuiltOn  \
# 42          0             0            0           0          NaN     NaN
# 300       300             0            0           0        token     ETH
# 365         0             0            0           0          NaN     NaN
# 404         0             0            0           0          NaN     NaN
# 433       NaN           NaN          NaN         NaN          NaN     NaN
#
#                            SmartContractAddress DecimalPoints Difficulty  \
# 42                                          NaN           NaN        NaN
# 300  0xaec98a708810414878c3bcdf46aad31ded4a4557            18        NaN
# 365                                         NaN           NaN        NaN
# 404                                         NaN           NaN        NaN
# 433                                         NaN           NaN        NaN
#
#     AlgorithmType
# 42            NaN
# 300           NaN
# 365           NaN
# 404           NaN
# 433           NaN
#
# [5 rows x 36 columns]

# %%
# Select desired columns from above dataframe and save it as 'crypto_df'
crypto_df = crypto_df[['CoinName', 'Algorithm', 'IsTrading', 'ProofType', 
                         'TotalCoinsMined', 'CirculatingSupply']]
crypto_df
# Out:
#                  CoinName Algorithm IsTrading ProofType TotalCoinsMined  \
# 42                42 Coin    Scrypt      True   PoW/PoS               0
# 300             300 token       N/A      True       N/A             300
# 365               365Coin       X11      True   PoW/PoS               0
# 404               404Coin    Scrypt      True   PoW/PoS               0
# 433             433 Token       N/A     False       N/A             NaN
# ...                   ...       ...       ...       ...             ...
# MSA     My Shiba Academia       N/A      True       N/A     3.97802e+09
# JPAW             Jpaw Inu       N/A      True       N/A   1000000000000
# L                   L inu       N/A      True       N/A   1000000000000
# SUNOLD          Sun Token    TRC-20      True       N/A        19900730
# SUN             Sun Token    TRC-20      True       N/A     1.99007e+10
#
#        CirculatingSupply
# 42                     0
# 300                    0
# 365                    0
# 404                    0
# 433                  NaN
# ...                  ...
# MSA                    0
# JPAW                   0
# L                      0
# SUNOLD                 0
# SUN                    0
#
# [7281 rows x 6 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# check the shape (rows and columns) of dataframe
crypto_df.shape
# Out:
# (7281, 6)

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True].copy()
crypto_df.shape
# Out:
# (5775, 6)

# %%
# Replace Algorithm column empty cells with numpy nan 
crypto_df['Algorithm'].replace('', np.nan, inplace=True)

# %%
# drop na from column 'Algorithm'
crypto_df.dropna(subset=['Algorithm'], inplace=True)

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df.loc[crypto_df['Algorithm'] != 'N/A' ].copy()
crypto_df.shape
# Out:
# (1612, 6)

# %%
# Remove the "IsTrading" column
crypto_df.drop(columns=['IsTrading'], inplace = True)

# %%
# check the shape (rows and columns) of dataframe
crypto_df.shape
# Out:
# (1612, 5)

# %%
# check the count for null values by columns
crypto_df.isnull().sum()
# Out:
# CoinName                0
# Algorithm               0
# ProofType               0
# TotalCoinsMined      1201
# CirculatingSupply    1199
# dtype: int64

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df.loc[crypto_df.TotalCoinsMined > 0].copy()
crypto_df.shape
# Out:
# (266, 5)

# %%
# check for any duplicates
print(f"Duplicate entries: {crypto_df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# check the count for null values by columns
crypto_df.isnull().sum()
# Out:
# CoinName             0
# Algorithm            0
# ProofType            0
# TotalCoinsMined      0
# CirculatingSupply    0
# dtype: int64

# %%
# Store the 'CoinName' column in its own DataFrame prior to dropping it from crypto_df. Plus save dataframe 
# in new dataframe named 'shoppings_df' for later usage
coin_df = pd.DataFrame(crypto_df['CoinName'], index=crypto_df.index)
shoppings_df = crypto_df
shoppings_df
# Out:
#                          CoinName     Algorithm ProofType TotalCoinsMined  \
# NSR                      NuShares           PoS       PoS     6.16681e+09
# TRI                Triangles Coin           X13   PoW/PoS          189108
# CMTC                    CometCoin        Scrypt       PoW          872830
# CHAT                     OpenChat        Scrypt   PoW/PoS      1000000000
# QRL      Quantum Resistant Ledger       RandomX       PoW     7.51781e+07
# ...                           ...           ...       ...             ...
# AURORAC                Auroracoin        Scrypt   PoW/PoS     9.98656e+07
# AUR                         AUREO  BEP-20 Token       N/A      1.9561e+07
# XEC                         eCash       SHA-256       PoW     1.88814e+13
# SUNOLD                  Sun Token        TRC-20       N/A        19900730
# SUN                     Sun Token        TRC-20       N/A     1.99007e+10
#
#         CirculatingSupply
# NSR                     0
# TRI                     0
# CMTC                    0
# CHAT                    0
# QRL                     0
# ...                   ...
# AURORAC                 0
# AUR                     0
# XEC           1.88814e+13
# SUNOLD                  0
# SUN                     0
#
# [266 rows x 5 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns=['CoinName'])
crypto_df.head(10)
# Out:
#      Algorithm ProofType TotalCoinsMined CirculatingSupply
# NSR        PoS       PoS     6.16681e+09                 0
# TRI        X13   PoW/PoS          189108                 0
# CMTC    Scrypt       PoW          872830                 0
# CHAT    Scrypt   PoW/PoS      1000000000                 0
# QRL    RandomX       PoW     7.51781e+07                 0
# AMB     Dagger       PoA       819409195                 0
# BTCZ  Equihash       PoW     1.04889e+10                 0
# PURA       X11       PoW     1.88359e+08                 0
# BTCP  Equihash       PoW     3.81888e+06                 0
# ADK      IMesh       PoW        25000000                 0

# %%
# Create dummy variables for text features only using 'Algorithm' and 'ProofType' columns
crypto_df = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
crypto_df
# Out:
#         TotalCoinsMined CirculatingSupply  Algorithm_Autolykos  \
# NSR         6.16681e+09                 0                    0
# TRI              189108                 0                    0
# CMTC             872830                 0                    0
# CHAT         1000000000                 0                    0
# QRL         7.51781e+07                 0                    0
# ...                 ...               ...                  ...
# AURORAC     9.98656e+07                 0                    0
# AUR          1.9561e+07                 0                    0
# XEC         1.88814e+13       1.88814e+13                    0
# SUNOLD         19900730                 0                    0
# SUN         1.99007e+10                 0                    0
#
#          Algorithm_BEP-2  Algorithm_BEP-2 Token  Algorithm_BEP-20 Token  \
# NSR                    0                      0                       0
# TRI                    0                      0                       0
# CMTC                   0                      0                       0
# CHAT                   0                      0                       0
# QRL                    0                      0                       0
# ...                  ...                    ...                     ...
# AURORAC                0                      0                       0
# AUR                    0                      0                       1
# XEC                    0                      0                       0
# SUNOLD                 0                      0                       0
# SUN                    0                      0                       0
#
#          Algorithm_BEP2 Token  Algorithm_BLAKE256  Algorithm_BMW512 / Echo512  \
# NSR                         0                   0                           0
# TRI                         0                   0                           0
# CMTC                        0                   0                           0
# CHAT                        0                   0                           0
# QRL                         0                   0                           0
# ...                       ...                 ...                         ...
# AURORAC                     0                   0                           0
# AUR                         0                   0                           0
# XEC                         0                   0                           0
# SUNOLD                      0                   0                           0
# SUN                         0                   0                           0
#
#          Algorithm_Blake2B + SHA3  ...  ProofType_PoW  ProofType_PoW/PoS  \
# NSR                             0  ...              0                  0
# TRI                             0  ...              0                  1
# CMTC                            0  ...              1                  0
# CHAT                            0  ...              0                  1
# QRL                             0  ...              1                  0
# ...                           ...  ...            ...                ...
# AURORAC                         0  ...              0                  1
# AUR                             0  ...              0                  0
# XEC                             0  ...              1                  0
# SUNOLD                          0  ...              0                  0
# SUN                             0  ...              0                  0
#
#          ProofType_PoW/PoSe  ProofType_PoW/nPoS  ProofType_Proof of Authority  \
# NSR                       0                   0                             0
# TRI                       0                   0                             0
# CMTC                      0                   0                             0
# CHAT                      0                   0                             0
# QRL                       0                   0                             0
# ...                     ...                 ...                           ...
# AURORAC                   0                   0                             0
# AUR                       0                   0                             0
# XEC                       0                   0                             0
# SUNOLD                    0                   0                             0
# SUN                       0                   0                             0
#
#          ProofType_SPoS  ProofType_TPoS  ProofType_Zero-Knowledge Proof  \
# NSR                   0               0                               0
# TRI                   0               0                               0
# CMTC                  0               0                               0
# CHAT                  0               0                               0
# QRL                   0               0                               0
# ...                 ...             ...                             ...
# AURORAC               0               0                               0
# AUR                   0               0                               0
# XEC                   0               0                               0
# SUNOLD                0               0                               0
# SUN                   0               0                               0
#
#          ProofType_dPoW  ProofType_dPoW/PoW
# NSR                   0                   0
# TRI                   0                   0
# CMTC                  0                   0
# CHAT                  0                   0
# QRL                   0                   0
# ...                 ...                 ...
# AURORAC               0                   0
# AUR                   0                   0
# XEC                   0                   0
# SUNOLD                0                   0
# SUN                   0                   0
#
# [266 rows x 86 columns]

# %%
# Standardize data
crypto_scaled = StandardScaler().fit_transform(crypto_df)
print(crypto_scaled[0:3])
# Out:
# [[-0.06142951 -0.06267677 -0.06142951 -0.10680283 -0.06142951 -0.85280287
#   -0.06142951 -0.08703883 -0.06142951 -0.06142951 -0.10680283 -0.08703883
#   -0.08703883 -0.06142951 -0.06142951 -0.2076951  -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.2076951  -0.06142951 -0.06142951 -0.16439899
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.13840913
#   -0.08703883 -0.06142951 -0.06142951 -0.06142951 -0.08703883  7.22495675
#   -0.06142951 -0.10680283 -0.08703883 -0.22667907 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.3002731  -0.06142951 -0.13840913 -0.06142951
#   -0.08703883 -0.12356041 -0.06142951 -0.15191091 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.17609018
#   -0.06142951 -0.06142951 -1.07012209 -0.08703883 -0.06142951 -0.06142951
#    5.05964426 -0.06142951 -0.06142951 -0.06142951 -0.5454915  -0.31491833
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951
#   -0.06142951 -0.06142951]
#  [-0.06142951 -0.06267677 -0.06142951 -0.10680283 -0.06142951 -0.85280287
#   -0.06142951 -0.08703883 -0.06142951 -0.06142951 -0.10680283 -0.08703883
#   -0.08703883 -0.06142951 -0.06142951 -0.2076951  -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.2076951  -0.06142951 -0.06142951 -0.16439899
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.13840913
#   -0.08703883 -0.06142951 -0.06142951 -0.06142951 -0.08703883 -0.13840913
#   -0.06142951 -0.10680283 -0.08703883 -0.22667907 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.3002731  -0.06142951 -0.13840913 -0.06142951
#   -0.08703883 -0.12356041 -0.06142951  6.58280589 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.17609018
#   -0.06142951 -0.06142951 -1.07012209 -0.08703883 -0.06142951 -0.06142951
#   -0.19764235 -0.06142951 -0.06142951 -0.06142951 -0.5454915   3.17542648
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951
#   -0.06142951 -0.06142951]
#  [-0.06142951 -0.06267677 -0.06142951 -0.10680283 -0.06142951 -0.85280287
#   -0.06142951 -0.08703883 -0.06142951 -0.06142951 -0.10680283 -0.08703883
#   -0.08703883 -0.06142951 -0.06142951 -0.2076951  -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.2076951  -0.06142951 -0.06142951 -0.16439899
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.13840913
#   -0.08703883 -0.06142951 -0.06142951 -0.06142951 -0.08703883 -0.13840913
#   -0.06142951 -0.10680283 -0.08703883 -0.22667907 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951  3.33030165 -0.06142951 -0.13840913 -0.06142951
#   -0.08703883 -0.12356041 -0.06142951 -0.15191091 -0.08703883 -0.06142951
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.17609018
#   -0.06142951 -0.06142951 -1.07012209 -0.08703883 -0.06142951 -0.06142951
#   -0.19764235 -0.06142951 -0.06142951 -0.06142951  1.83320914 -0.31491833
#   -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951 -0.06142951
#   -0.06142951 -0.06142951]]

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(crypto_scaled)

# %%
# Create a DataFrame with the principal components data
df_crypto_pca = pd.DataFrame(
    data=crypto_pca, columns=["PC 1", "PC 2", "PC 3"], index=crypto_df.index
)
df_crypto_pca
# Out:
#              PC 1      PC 2      PC 3
# NSR      1.350895  0.669157 -0.104060
# TRI      1.523606  0.288847 -0.054754
# CMTC     2.058974 -0.839132  0.085619
# CHAT     1.785087 -0.127333 -0.003379
# QRL      2.108758 -1.168459  0.128725
# ...           ...       ...       ...
# AURORAC  1.785087 -0.127333 -0.003379
# AUR     -1.744890 -0.114581  0.013975
# XEC      3.098308 -2.296771  0.254700
# SUNOLD  -1.075573 -0.034451  0.003939
# SUN     -1.075573 -0.034451  0.003939
#
# [266 rows x 3 columns]

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
# Find the best value for k using Elbow Curve
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(crypto_df)
    inertia.append(km.inertia_)


# Create the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:8: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:8: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.

# %%
# Create Elbow chart using altair
alt.Chart(df_elbow).mark_line().encode(
    x='k',
    y='inertia'
).interactive()
# Out:
# alt.Chart(...)

# %%
# Initialize the K-Means model
model = KMeans(n_clusters= 4, random_state=0)

# Fit the model
model.fit(df_crypto_pca)

# Predict clusters
predictions = model.predict(df_crypto_pca)

# Add the predicted class columns
df_crypto_pca["class"] = model.labels_
df_crypto_pca.head()
# Out:
#           PC 1      PC 2      PC 3  class
# NSR   1.350895  0.669157 -0.104060      1
# TRI   1.523606  0.288847 -0.054754      1
# CMTC  2.058974 -0.839132  0.085619      1
# CHAT  1.785087 -0.127333 -0.003379      1
# QRL   2.108758 -1.168459  0.128725      1

# %%
# combined crypto data as clustered_df, drop index column, and set index 'Symbol'
clustered_df = pd.concat([shoppings_df, df_crypto_pca], axis=1)
clustered_df.head(10)
# Out:
#                       CoinName Algorithm ProofType TotalCoinsMined  \
# NSR                   NuShares       PoS       PoS     6.16681e+09
# TRI             Triangles Coin       X13   PoW/PoS          189108
# CMTC                 CometCoin    Scrypt       PoW          872830
# CHAT                  OpenChat    Scrypt   PoW/PoS      1000000000
# QRL   Quantum Resistant Ledger   RandomX       PoW     7.51781e+07
# AMB                      Amber    Dagger       PoA       819409195
# BTCZ                  BitcoinZ  Equihash       PoW     1.04889e+10
# PURA                      Pura       X11       PoW     1.88359e+08
# BTCP           Bitcoin Private  Equihash       PoW     3.81888e+06
# ADK               Aidos Kuneen     IMesh       PoW        25000000
#
#      CirculatingSupply      PC 1      PC 2      PC 3  class
# NSR                  0  1.350895  0.669157 -0.104060      1
# TRI                  0  1.523606  0.288847 -0.054754      1
# CMTC                 0  2.058974 -0.839132  0.085619      1
# CHAT                 0  1.785087 -0.127333 -0.003379      1
# QRL                  0  2.108758 -1.168459  0.128725      1
# AMB                  0  1.498480  8.342785  9.892108      2
# BTCZ                 0  2.106142 -1.088856  0.118785      1
# PURA                 0  1.984316 -0.646093  0.063369      1
# BTCP                 0  2.106142 -1.088856  0.118785      1
# ADK                  0  2.019300 -0.978931  0.108173      1

# %% [markdown]
# ### Visualizing Results
#
# #### 2D-Scatter with Clusters

# %%
# Create a 2D-Scatter with the PCA data and the clusters
alt.Chart(clustered_df).mark_circle(size=60).encode(
    x='PC 1',
    y='PC 2',
    color='class',
    tooltip=['CoinName', 'Algorithm', 'TotalCoinsMined', 'CirculatingSupply'],
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# for MinMaxscaler usage, we will save totalcoinsmined and CirculatingSupply columns in new dataframe
clustered_df_temp = clustered_df[['TotalCoinsMined', 'CirculatingSupply']]
clustered_df_temp
# Out:
#         TotalCoinsMined CirculatingSupply
# NSR         6.16681e+09                 0
# TRI              189108                 0
# CMTC             872830                 0
# CHAT         1000000000                 0
# QRL         7.51781e+07                 0
# ...                 ...               ...
# AURORAC     9.98656e+07                 0
# AUR          1.9561e+07                 0
# XEC         1.88814e+13       1.88814e+13
# SUNOLD         19900730                 0
# SUN         1.99007e+10                 0
#
# [266 rows x 2 columns]

# %%
# Table with tradable cryptos without principal components, TotalcoinsMined, CirculatingSupply
clustered_df.drop(columns=['TotalCoinsMined', 'CirculatingSupply', 'PC 1', 'PC 2', 'PC 3'], inplace = True)
clustered_df
# Out:
#                          CoinName     Algorithm ProofType  class
# NSR                      NuShares           PoS       PoS      1
# TRI                Triangles Coin           X13   PoW/PoS      1
# CMTC                    CometCoin        Scrypt       PoW      1
# CHAT                     OpenChat        Scrypt   PoW/PoS      1
# QRL      Quantum Resistant Ledger       RandomX       PoW      1
# ...                           ...           ...       ...    ...
# AURORAC                Auroracoin        Scrypt   PoW/PoS      1
# AUR                         AUREO  BEP-20 Token       N/A      0
# XEC                         eCash       SHA-256       PoW      1
# SUNOLD                  Sun Token        TRC-20       N/A      0
# SUN                     Sun Token        TRC-20       N/A      0
#
# [266 rows x 4 columns]

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Use MinMaxScaler on clusterd_df_temp we previously created 
scaler = MinMaxScaler()
tradable_crypto_scaled = scaler.fit_transform(clustered_df_temp)
print(tradable_crypto_scaled[0:10])
# Out:
# [[6.22264609e-17 0.00000000e+00]
#  [1.88266984e-21 0.00000000e+00]
#  [8.78180385e-21 0.00000000e+00]
#  [1.00905287e-17 0.00000000e+00]
#  [7.58562701e-19 0.00000000e+00]
#  [8.26826741e-18 0.00000000e+00]
#  [1.05838758e-16 0.00000000e+00]
#  [1.90062094e-18 0.00000000e+00]
#  [3.85090650e-20 0.00000000e+00]
#  [2.52238322e-19 0.00000000e+00]]

# %%
# Create dataframe using tradable_crypto_scaled, Rename columns for scatter plot usage
crypto_scaled_df = pd.DataFrame(tradable_crypto_scaled, index=clustered_df.index)
crypto_scaled_df.rename(columns={0:'TotalCoinsMined', 1: 'TotalCoinSupply'}, inplace = True)
crypto_scaled_df
# Out:
#          TotalCoinsMined  TotalCoinSupply
# NSR         6.222646e-17              0.0
# TRI         1.882670e-21              0.0
# CMTC        8.781804e-21              0.0
# CHAT        1.009053e-17              0.0
# QRL         7.585627e-19              0.0
# ...                  ...              ...
# AURORAC     1.007674e-18              0.0
# AUR         1.973560e-19              0.0
# XEC         1.905241e-13              1.0
# SUNOLD      2.007839e-19              0.0
# SUN         2.008094e-16              0.0
#
# [266 rows x 2 columns]

# %%
# combine scaled dataframe with clustered dataframe using index
tradable_crypto_df = pd.concat([crypto_scaled_df, clustered_df], axis = 1)
tradable_crypto_df
# Out:
#          TotalCoinsMined  TotalCoinSupply                  CoinName  \
# NSR         6.222646e-17              0.0                  NuShares
# TRI         1.882670e-21              0.0            Triangles Coin
# CMTC        8.781804e-21              0.0                 CometCoin
# CHAT        1.009053e-17              0.0                  OpenChat
# QRL         7.585627e-19              0.0  Quantum Resistant Ledger
# ...                  ...              ...                       ...
# AURORAC     1.007674e-18              0.0                Auroracoin
# AUR         1.973560e-19              0.0                     AUREO
# XEC         1.905241e-13              1.0                     eCash
# SUNOLD      2.007839e-19              0.0                 Sun Token
# SUN         2.008094e-16              0.0                 Sun Token
#
#             Algorithm ProofType  class
# NSR               PoS       PoS      1
# TRI               X13   PoW/PoS      1
# CMTC           Scrypt       PoW      1
# CHAT           Scrypt   PoW/PoS      1
# QRL           RandomX       PoW      1
# ...               ...       ...    ...
# AURORAC        Scrypt   PoW/PoS      1
# AUR      BEP-20 Token       N/A      0
# XEC           SHA-256       PoW      1
# SUNOLD         TRC-20       N/A      0
# SUN            TRC-20       N/A      0
#
# [266 rows x 6 columns]

# %%
# Create a 2D-Scatter 
alt.Chart(tradable_crypto_df).mark_circle(size=60).encode(
    x='TotalCoinsMined',
    y='TotalCoinSupply',
    color='class',
    tooltip=['CoinName', 'Algorithm', 'TotalCoinsMined', 'TotalCoinSupply']
    
).interactive()
# Out:
# alt.Chart(...)
